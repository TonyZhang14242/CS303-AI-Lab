# %%
def floyd(graph, start, end):
    """
    Args:
        graph: a given graph, as an adjacency matrix, the non-connected edge are set to infinity
        start: the index of the start vertex
        end: the index of the end vertex

    Returns:
        distance: the distance from the start point to the end point.

    sample:
    input (file):
    1          =>neighbors of node 0
    6          =>distances of (0,1)
    2 4        =>neighbors of node 1
    3 10       =>distances of (1,2) (1,4)
    3          =>neighbors of node 2
    7          =>distances of node (2,3)
    4          =>neighbors of node 3
    9          =>distances of node (3,4)
    0 3        =>neighbors of node 4
    3 9        =>distances of node (4,0) (4,3)

    graph: a distance matrix from above file
    [[0, 6.0, inf, inf, inf],
    [inf, 0, 3.0, inf, 10.0],
    [inf, inf, 0, 7.0, inf],
    [inf, inf, inf, 0, 9.0],
    [3.0, inf, inf, 9.0, 0]]

    output:
    16
    """

    ##############
    #  Please write your own code in the given space.
    for i in range(n):
        for j in range(n):
            for k in range(n):
                if graph[j][i]+graph[i][k]<graph[j][k]:
                    graph[j][k]=graph[j][i]+graph[i][k]

    #############

    #graph = [[]] # you should build a distance matrix (from the original graph) which include all the distances between any two vertexs.

    #############

    distance = graph[start][end]

    return distance

# %%
# test block
test_case = 3
with open(f'test_cases/problem2/{test_case}.txt', 'r') as f:
    content = f.read().strip()
    lines = content.split('\n')
n = len(lines) // 2
graph = [[float('inf')] * n for _ in range(n)]
for i in range(n):
    graph[i][i] = 0
for i in range(n):
    neighbors = [*map(int, lines[2 * i].strip().split(' '))]
    distances = [*map(float, lines[2 * i + 1].strip().split(' '))]
    for j in range(len(neighbors)):
        k = neighbors[j]
        graph[i][k] = distances[j]
print(graph)
print(floyd(graph, 0, n - 1))
# Out:
# [[0, 220.0, 162.0, inf, 322.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, 264.0, 85.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, 144.0, inf, inf, inf, inf, inf, 95.0, inf, inf, inf, inf, inf, 268.0, inf, inf, inf, 76.0, inf, inf, 403.0, inf, inf, 343.0, inf, inf, inf, inf, inf, inf, inf, 233.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 138.0, 249.0, 297.0, inf, inf, 228.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 292.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, 294.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 56.0, inf, 203.0, inf, inf, inf, inf, inf, inf, 135.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, 168.0, inf, inf, 76.0, inf, 367.0, inf, inf, 308.0, inf, 239.0, inf, inf, 123.0, inf, inf, inf, inf, inf, inf, inf, 229.0, inf, inf, inf, 26.0, inf, inf, inf, 250.0, inf, inf, inf, inf, 272.0, inf, 231.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 90.0, inf, 311.0, inf, inf, inf, 145.0, inf, inf, inf], [inf, 0, 304.0, inf, inf, 491.0, inf, inf, inf, inf, inf, 194.0, inf, 227.0, inf, inf, inf, inf, inf, inf, inf, 404.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 361.0, inf, inf, inf, inf, inf, inf, inf, 244.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 185.0, 23.0, inf, inf, inf, inf, inf, 142.0, inf, inf, inf, 242.0, inf, inf, inf, inf, inf, 112.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 34.0, inf, inf, inf, inf, 103.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 54.0, inf, inf, inf, 312.0, inf, inf, inf, inf, inf, inf, 170.0, inf, inf, 382.0, 324.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 108.0, inf, inf, inf, inf, inf, 379.0, 458.0, 477.0, inf, inf, inf, 305.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 487.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 72.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 406.0, inf, inf, inf, inf, 530.0, inf, 105.0, inf, inf, inf, inf, 187.0], [inf, inf, 0, 70.0, 172.0, inf, inf, inf, inf, inf, inf, 113.0, inf, inf, inf, 76.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 191.0, inf, 325.0, inf, 125.0, inf, inf, inf, inf, inf, 143.0, inf, inf, inf, inf, 170.0, inf, inf, inf, inf, inf, 97.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 189.0, 239.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 247.0, inf, inf, 231.0, inf, inf, inf, 223.0, inf, inf, inf, 154.0, inf, inf, inf, inf, inf, 247.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 85.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 226.0, inf, inf, inf, 106.0, inf, inf, inf, 151.0, inf, inf, 205.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 318.0, inf, inf], [inf, inf, inf, 0, 189.0, inf, inf, inf, 408.0, inf, inf, inf, 218.0, 95.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 86.0, 226.0, inf, inf, inf, inf, inf, inf, 244.0, inf, inf, inf, inf, inf, 306.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 327.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 244.0, inf, inf, inf, inf, inf, inf, inf, inf, 266.0, inf, inf, inf, 182.0, inf, inf, inf, inf, 285.0, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 136.0, inf, inf, inf, 315.0, inf, i ...
# 177.0
